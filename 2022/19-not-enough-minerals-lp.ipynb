# %% [markdown]
# https://adventofcode.com/2022/day/19
#
# Found an example of linear programming approach in https://www.reddit.com/r/adventofcode/comments/zpihwi/2022_day_19_solutions/

# %%
import re
from functools import reduce
import operator
import pulp as lp

# %%
with open("data/19.txt") as fh:
    data = fh.read()

# %%
testdata = """\
Blueprint 1: Each ore robot costs 4 ore. Each clay robot costs 2 ore. Each obsidian robot costs 3 ore and 14 clay. Each geode robot costs 2 ore and 7 obsidian.
Blueprint 2: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 8 clay. Each geode robot costs 3 ore and 12 obsidian
"""

# %%
def load_data(data):
    L = []
    for line in data.strip().splitlines():
        bp, ore_ore, clay_ore, obs_ore, obs_clay, geode_ore, geode_obs = (
            int(i) for i in re.findall(r"[+-]?\d+", line)
        )
        D = {
            "bp": bp,
            "robots": {
                "ore": {"ore": ore_ore},
                "clay": {"ore": clay_ore},
                "obs": {"ore": obs_ore, "clay": obs_clay},
                "geode": {"ore": geode_ore, "obs": geode_obs},
            },
        }
        L.append(D)
    return L


load_data(testdata)
# Out:
# [{'bp': 1,
#   'robots': {'ore': {'ore': 4},
#    'clay': {'ore': 2},
#    'obs': {'ore': 3, 'clay': 14},
#    'geode': {'ore': 2, 'obs': 7}}},
#  {'bp': 2,
#   'robots': {'ore': {'ore': 2},
#    'clay': {'ore': 3},
#    'obs': {'ore': 3, 'clay': 8},
#    'geode': {'ore': 3, 'obs': 12}}}]

# %%
bps = load_data(testdata)
bps
# Out:
# [{'bp': 1,
#   'robots': {'ore': {'ore': 4},
#    'clay': {'ore': 2},
#    'obs': {'ore': 3, 'clay': 14},
#    'geode': {'ore': 2, 'obs': 7}}},
#  {'bp': 2,
#   'robots': {'ore': {'ore': 2},
#    'clay': {'ore': 3},
#    'obs': {'ore': 3, 'clay': 8},
#    'geode': {'ore': 3, 'obs': 12}}}]

# %%
bps[0]["robots"]
# Out:
# {'ore': {'ore': 4},
#  'clay': {'ore': 2},
#  'obs': {'ore': 3, 'clay': 14},
#  'geode': {'ore': 2, 'obs': 7}}

# %%
def collect_geodes(bp, timelimit=24):
    problem = lp.LpProblem(f"problem:{bp['bp']:02d}", lp.LpMaximize)
    robots_geo = [
        lp.LpVariable(f"robots_geo{i:02d}", 0, 0 if i == 0 else None, lp.LpInteger)
        for i in range(timelimit)
    ]
    problem += sum(robots_geo)

    robots_ore = []
    robots_cly = []
    robots_obs = []
    onhand_ore = []
    onhand_cly = []
    onhand_obs = []
    build_ore = []
    build_cly = []
    build_obs = []
    build_geo = []

    for i in range(timelimit):
        robots_ore.append(
            lp.LpVariable(f"robots_ore{i:02d}", 1 if i == 0 else 0, 1 if i == 0 else None, lp.LpInteger)
        )
        robots_cly.append(
            lp.LpVariable(f"robots_cly{i:02d}", 0, 0 if i == 0 else None, lp.LpInteger)
        )
        robots_obs.append(
            lp.LpVariable(f"robots_obs{i:02d}", 0, 0 if i == 0 else None, lp.LpInteger)
        )
        onhand_ore.append(
            lp.LpVariable(f"onhand_ore{i:02d}", 0, 0 if i == 0 else None, lp.LpInteger)
        )
        onhand_cly.append(
            lp.LpVariable(f"onhand_cly{i:02d}", 0, 0 if i == 0 else None, lp.LpInteger)
        )
        onhand_obs.append(
            lp.LpVariable(f"onhand_obs{i:02d}", 0, 0 if i == 0 else None, lp.LpInteger)
        )
        build_ore.append(lp.LpVariable(f"build_ore{i:02d}", 0, 1, lp.LpInteger))
        build_cly.append(lp.LpVariable(f"build_cly{i:02d}", 0, 1, lp.LpInteger))
        build_obs.append(lp.LpVariable(f"build_obs{i:02d}", 0, 1, lp.LpInteger))
        build_geo.append(lp.LpVariable(f"build_geo{i:02d}", 0, 1, lp.LpInteger))

        # Build zero or one robot per turn
        problem += build_ore[-1] + build_cly[-1] + build_obs[-1] + build_geo[-1] <= 1

        if i != 0:
            # Robot costs
            problem += onhand_ore[-2] - build_ore[-1] * bp["robots"]["ore"]["ore"] >= 0
            problem += onhand_ore[-2] - build_cly[-1] * bp["robots"]["clay"]["ore"] >= 0
            problem += onhand_ore[-2] - build_obs[-1] * bp["robots"]["obs"]["ore"] >= 0
            problem += onhand_cly[-2] - build_obs[-1] * bp["robots"]["obs"]["clay"] >= 0
            problem += (
                onhand_ore[-2] - build_geo[-1] * bp["robots"]["geode"]["ore"] >= 0
            )
            problem += (
                onhand_obs[-2] - build_geo[-1] * bp["robots"]["geode"]["obs"] >= 0
            )
            # Resources on hand
            problem += (
                onhand_ore[-1]
                == onhand_ore[-2]
                + robots_ore[-2]
                - build_ore[-1] * bp["robots"]["ore"]["ore"]
                - build_cly[-1] * bp["robots"]["clay"]["ore"]
                - build_obs[-1] * bp["robots"]["obs"]["ore"]
                - build_geo[-1] * bp["robots"]["geode"]["ore"]
            )
            problem += (
                onhand_cly[-1]
                == onhand_cly[-2]
                + robots_cly[-2]
                - build_obs[-1] * bp["robots"]["obs"]["clay"]
            )
            problem += (
                onhand_obs[-1]
                == onhand_obs[-2]
                + robots_obs[-2]
                - build_geo[-1] * bp["robots"]["geode"]["obs"]
            )
            # Number of robots
            problem += robots_ore[-1] == robots_ore[-2] + build_ore[-1]
            problem += robots_cly[-1] == robots_cly[-2] + build_cly[-1]
            problem += robots_obs[-1] == robots_obs[-2] + build_obs[-1]
            problem += robots_geo[i] == robots_geo[i-1] + build_geo[-1]

    status = problem.solve()
    return problem.objective.value()

# %%
# %%time
bps = load_data(data)
sum(bp['bp'] * collect_geodes(bp, 24) for bp in bps)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e56c66ba2ca04e6b9ea16fdb222218da-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e56c66ba2ca04e6b9ea16fdb222218da-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1874 RHS
# At line 2198 BOUNDS
# At line 2463 ENDATA
# Problem MODEL has 323 rows, 264 columns and 993 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.80994 - 0.00 seconds
# Cgl0003I 4 fixed, 95 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 52 tightened bounds, 45 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 14 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 28 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 126 rows, 93 columns (93 integer (50 of which binary)) and 552 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 5 integer variables out of 93 objects (93 integer) have costs - high priority
# Cbc0045I branch on satisfied Y create fake objective Y random cost Y
# Cbc0038I Initial state - 50 integers unsatisfied sum - 13.2363
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 0 iterations 36
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 126 rows 93 columns, reduced to 90 rows 60 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -1.19394
# Cbc0038I Pass   2: suminf.    7.79719 (44) obj. -1.19394 iterations 12
# Cbc0038I Pass   3: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass   4: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass   5: suminf.    7.40949 (32) obj. -1.19394 iterations 10
# Cbc0038I Pass   6: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass   7: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass   8: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass   9: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  10: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  11: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  12: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  13: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  14: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  15: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  16: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  17: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  18: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  19: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  20: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  21: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  22: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  23: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  24: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  25: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  26: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  27: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  28: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  29: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  30: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  31: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  32: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  33: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  34: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  35: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  36: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  37: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  38: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  39: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  40: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  41: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  42: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  43: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  44: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  45: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  46: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  47: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  48: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  49: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  50: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  51: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  52: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  53: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  54: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  55: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  56: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  57: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  58: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  59: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  60: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  61: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  62: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  63: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  64: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  65: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  66: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  67: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  68: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  69: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  70: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  71: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  72: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  73: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  74: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  75: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  76: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  77: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  78: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  79: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  80: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  81: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  82: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  83: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  84: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  85: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  86: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  87: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  88: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  89: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  90: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  91: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  92: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  93: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  94: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass  95: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass  96: suminf.    6.75163 (31) obj. -1.19394 iterations 2
# Cbc0038I Pass  97: suminf.    6.26282 (30) obj. -1.19394 iterations 9
# Cbc0038I Pass  98: suminf.    5.77688 (29) obj. -1.19394 iterations 3
# Cbc0038I Pass  99: suminf.    9.07923 (37) obj. -1.79819 iterations 4
# Cbc0038I Pass 100: suminf.    7.40949 (32) obj. -1.19394 iterations 9
# Cbc0038I Pass 101: suminf.    8.22655 (50) obj. -1.19394 iterations 14
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 126 rows 93 columns, reduced to 93 rows 63 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 0 - took 0.03 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 126 rows 93 columns, reduced to 90 rows 60 columns
# Cbc0031I 11 added rows had average density of 23.909091
# Cbc0013I At root node, 91 cuts changed objective from -2.9402857 to -0.090743133 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 17 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 122 row cuts average 44.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 159 row cuts average 37.9 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 0, took 174 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -2.94029 to -0.0907431
# Probing was tried 4 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Gomory was tried 4 times and created 122 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 4 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 4 times and created 159 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -0.00000000
# Enumerated nodes:               0
# Total iterations:               174
# Time (CPU seconds):             0.08
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.08   (Wallclock seconds):       0.09
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/13962def4fab4b71bcc8873d520d0f45-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/13962def4fab4b71bcc8873d520d0f45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1874 RHS
# At line 2198 BOUNDS
# At line 2463 ENDATA
# Problem MODEL has 323 rows, 264 columns and 993 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.10899 - 0.00 seconds
# Cgl0003I 4 fixed, 81 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 42 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 28 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 22 tightened bounds, 28 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 7 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 120 rows, 95 columns (95 integer (52 of which binary)) and 513 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 4 integer variables out of 95 objects (95 integer) have costs - high priority
# Cbc0045I branch on satisfied Y create fake objective Y random cost Y
# Cbc0038I Initial state - 44 integers unsatisfied sum - 12.5346
# Cbc0038I Pass   1: suminf.    3.66667 (11) obj. 0 iterations 28
# Cbc0038I Pass   2: suminf.    3.66667 (11) obj. 0 iterations 0
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 0 iterations 1
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Before mini branch and bound, 37 integers at bound fixed and 0 continuous of which 8 were internal integer and 0 internal continuous
# Cbc0038I Full problem 120 rows 95 columns, reduced to 47 rows 34 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -1.20685
# Cbc0038I Pass   4: suminf.    6.63141 (24) obj. -1.20685 iterations 4
# Cbc0038I Pass   5: suminf.    5.99403 (23) obj. -1.20685 iterations 6
# Cbc0038I Pass   6: suminf.    4.60372 (16) obj. -1.31889 iterations 12
# Cbc0038I Pass   7: suminf.    4.60372 (16) obj. -1.31889 iterations 0
# Cbc0038I Pass   8: suminf.    4.46769 (20) obj. -1.20685 iterations 3
# Cbc0038I Pass   9: suminf.    4.78897 (16) obj. -1.20685 iterations 2
# Cbc0038I Pass  10: suminf.    4.78897 (16) obj. -1.20685 iterations 0
# Cbc0038I Pass  11: suminf.    4.46769 (20) obj. -1.20685 iterations 1
# Cbc0038I Pass  12: suminf.    9.78372 (41) obj. -1.20685 iterations 17
# Cbc0038I Pass  13: suminf.    8.10570 (46) obj. -1.20685 iterations 10
# Cbc0038I Pass  14: suminf.    5.33491 (27) obj. -1.20685 iterations 9
# Cbc0038I Pass  15: suminf.    5.33491 (27) obj. -1.20685 iterations 0
# Cbc0038I Pass  16: suminf.    4.44378 (17) obj. -1.20685 iterations 12
# Cbc0038I Pass  17: suminf.    4.02745 (17) obj. -1.20685 iterations 3
# Cbc0038I Pass  18: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  19: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  20: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  21: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  22: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  23: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  24: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  25: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  26: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  27: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  28: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  29: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  30: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  31: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  32: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  33: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  34: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  35: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  36: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  37: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  38: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  39: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  40: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  41: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  42: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  43: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  44: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  45: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  46: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  47: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  48: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  49: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  50: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  51: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  52: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  53: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  54: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  55: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  56: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  57: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  58: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  59: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  60: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  61: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  62: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  63: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  64: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  65: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  66: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  67: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  68: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  69: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  70: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  71: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  72: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  73: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  74: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  75: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  76: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  77: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  78: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  79: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  80: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  81: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  82: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  83: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  84: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  85: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  86: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  87: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  88: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  89: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  90: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  91: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  92: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  93: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass  94: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass  95: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass  96: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass  97: suminf.    4.96756 (22) obj. -1.20685 iterations 0
# Cbc0038I Pass  98: suminf.    5.77698 (19) obj. -1.20685 iterations 4
# Cbc0038I Pass  99: suminf.    3.25620 (18) obj. -1.20685 iterations 5
# Cbc0038I Pass 100: suminf.    4.97009 (18) obj. -1.20685 iterations 4
# Cbc0038I Pass 101: suminf.    4.55376 (18) obj. -1.20685 iterations 3
# Cbc0038I Pass 102: suminf.    4.96756 (22) obj. -1.20685 iterations 3
# Cbc0038I Pass 103: suminf.   12.17158 (51) obj. -1.20685 iterations 24
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 120 rows 95 columns, reduced to 80 rows 58 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of 0 - took 0.03 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 120 rows 95 columns, reduced to 47 rows 34 columns
# Cbc0031I 6 added rows had average density of 30.5
# Cbc0013I At root node, 24 cuts changed objective from -3.0694499 to 0.44541659 in 36 passes
# Cbc0014I Cut generator 0 (Probing) - 13 row cuts average 3.1 elements, 7 column cuts (7 active)  in 0.018 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 869 row cuts average 68.6 elements, 0 column cuts (0 active)  in 0.022 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 229 row cuts average 37.6 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 0, took 1200 iterations and 0 nodes (0.20 seconds)
# Cbc0035I Maximum depth 0, 9 variables fixed on reduced cost
# Cuts at root node changed objective from -3.06945 to 0.445417
# Probing was tried 36 times and created 20 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# Gomory was tried 36 times and created 869 cuts of which 0 were active after adding rounds of cuts (0.022 seconds)
# Knapsack was tried 36 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Clique was tried 36 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 36 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 36 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# TwoMirCuts was tried 36 times and created 229 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -0.00000000
# Enumerated nodes:               0
# Total iterations:               1200
# Time (CPU seconds):             0.19
# Time (Wallclock seconds):       0.20
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.19   (Wallclock seconds):       0.20
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e55c179fc71642eea832bd5fd07b26bb-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e55c179fc71642eea832bd5fd07b26bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1874 RHS
# At line 2198 BOUNDS
# At line 2463 ENDATA
# Problem MODEL has 323 rows, 264 columns and 993 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9.7121 - 0.00 seconds
# Cgl0003I 5 fixed, 94 tightened bounds, 38 strengthened rows, 1 substitutions
# Cgl0003I 2 fixed, 54 tightened bounds, 46 strengthened rows, 2 substitutions
# Cgl0003I 2 fixed, 23 tightened bounds, 24 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 11 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 21 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 3 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0004I processed model has 135 rows, 98 columns (98 integer (52 of which binary)) and 581 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 50 integers unsatisfied sum - 11.521
# Cbc0038I Pass   1: suminf.    5.47368 (20) obj. 0 iterations 28
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 0 iterations 3
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Before mini branch and bound, 39 integers at bound fixed and 0 continuous of which 3 were internal integer and 0 internal continuous
# Cbc0038I Full problem 135 rows 98 columns, reduced to 56 rows 38 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -1 (0.03 seconds)
# Cbc0038I Round again with cutoff of -2.35858
# Cbc0038I Pass   3: suminf.    6.05912 (24) obj. -2.35858 iterations 4
# Cbc0038I Pass   4: suminf.    6.19663 (26) obj. -2.35858 iterations 6
# Cbc0038I Pass   5: suminf.    5.19700 (21) obj. -2.35858 iterations 1
# Cbc0038I Pass   6: suminf.    6.97979 (26) obj. -2.35858 iterations 2
# Cbc0038I Pass   7: suminf.    9.30166 (55) obj. -2.35858 iterations 20
# Cbc0038I Pass   8: suminf.   10.53388 (34) obj. -2.35858 iterations 3
# Cbc0038I Pass   9: suminf.    6.63545 (30) obj. -2.35858 iterations 10
# Cbc0038I Pass  10: suminf.    6.03987 (22) obj. -2.35858 iterations 2
# Cbc0038I Pass  11: suminf.    6.83476 (25) obj. -2.35858 iterations 2
# Cbc0038I Pass  12: suminf.    5.00292 (20) obj. -2.35858 iterations 1
# Cbc0038I Pass  13: suminf.   11.92178 (52) obj. -2.35858 iterations 13
# Cbc0038I Pass  14: suminf.   12.90810 (51) obj. -2.35858 iterations 4
# Cbc0038I Pass  15: suminf.   12.99879 (50) obj. -2.35858 iterations 4
# Cbc0038I Pass  16: suminf.   16.38975 (54) obj. -2.35858 iterations 9
# Cbc0038I Pass  17: suminf.   17.27944 (58) obj. -2.35858 iterations 5
# Cbc0038I Pass  18: suminf.    6.20495 (25) obj. -2.47399 iterations 8
# Cbc0038I Pass  19: suminf.    6.02769 (27) obj. -2.35858 iterations 3
# Cbc0038I Pass  20: suminf.    4.89791 (22) obj. -2.35858 iterations 8
# Cbc0038I Pass  21: suminf.    5.19700 (21) obj. -2.35858 iterations 5
# Cbc0038I Pass  22: suminf.    6.97979 (26) obj. -2.35858 iterations 1
# Cbc0038I Pass  23: suminf.    7.74310 (53) obj. -2.35858 iterations 16
# Cbc0038I Pass  24: suminf.    4.05440 (21) obj. -2.35858 iterations 11
# Cbc0038I Pass  25: suminf.    4.62163 (24) obj. -2.35858 iterations 4
# Cbc0038I Pass  26: suminf.    3.20299 (20) obj. -2.35858 iterations 2
# Cbc0038I Pass  27: suminf.   15.83443 (60) obj. -2.35858 iterations 27
# Cbc0038I Pass  28: suminf.   13.68155 (52) obj. -2.35858 iterations 10
# Cbc0038I Pass  29: suminf.   10.28681 (35) obj. -2.35858 iterations 6
# Cbc0038I Pass  30: suminf.    6.57422 (25) obj. -2.35858 iterations 5
# Cbc0038I Pass  31: suminf.    5.03269 (24) obj. -2.35858 iterations 3
# Cbc0038I Pass  32: suminf.    7.51756 (27) obj. -2.35858 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 135 rows 98 columns, reduced to 111 rows 77 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of -1 - took 0.03 seconds
# Cbc0012I Integer solution of -1 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 135 rows 98 columns, reduced to 24 rows 15 columns
# Cbc0031I 13 added rows had average density of 37.846154
# Cbc0013I At root node, 21 cuts changed objective from -5.5867163 to 0.23379653 in 45 passes
# Cbc0014I Cut generator 0 (Probing) - 22 row cuts average 4.3 elements, 11 column cuts (12 active)  in 0.024 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1073 row cuts average 74.3 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 224 row cuts average 43.3 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -1, took 1412 iterations and 0 nodes (0.23 seconds)
# Cbc0035I Maximum depth 0, 11 variables fixed on reduced cost
# Cuts at root node changed objective from -5.58672 to 0.233797
# Probing was tried 45 times and created 33 cuts of which 1 were active after adding rounds of cuts (0.024 seconds)
# Gomory was tried 45 times and created 1073 cuts of which 0 were active after adding rounds of cuts (0.027 seconds)
# Knapsack was tried 45 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 45 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 45 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 45 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# TwoMirCuts was tried 45 times and created 224 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               1412
# Time (CPU seconds):             0.23
# Time (Wallclock seconds):       0.24
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.23   (Wallclock seconds):       0.24
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e151389424f4449bbca0667f83f2844f-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e151389424f4449bbca0667f83f2844f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1874 RHS
# At line 2198 BOUNDS
# At line 2463 ENDATA
# Problem MODEL has 323 rows, 264 columns and 993 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 16.2629 - 0.00 seconds
# Cgl0003I 6 fixed, 96 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 51 tightened bounds, 51 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 18 tightened bounds, 33 strengthened rows, 2 substitutions
# Cgl0003I 0 fixed, 11 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 7 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 132 rows, 103 columns (103 integer (56 of which binary)) and 577 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 54 integers unsatisfied sum - 14.9809
# Cbc0038I Pass   1: suminf.    6.55556 (21) obj. -1 iterations 40
# Cbc0038I Pass   2: suminf.    7.91667 (25) obj. -1 iterations 8
# Cbc0038I Pass   3: suminf.    7.83333 (19) obj. -1 iterations 2
# Cbc0038I Pass   4: suminf.    4.33333 (13) obj. -1 iterations 5
# Cbc0038I Pass   5: suminf.    5.50000 (29) obj. -1 iterations 3
# Cbc0038I Pass   6: suminf.    4.33333 (13) obj. -1 iterations 2
# Cbc0038I Pass   7: suminf.    8.96852 (33) obj. -4.26667 iterations 17
# Cbc0038I Pass   8: suminf.    8.47778 (29) obj. -4.26667 iterations 5
# Cbc0038I Pass   9: suminf.    8.18182 (23) obj. -1 iterations 6
# Cbc0038I Pass  10: suminf.    4.58333 (19) obj. -1 iterations 1
# Cbc0038I Pass  11: suminf.    4.71717 (39) obj. -1 iterations 14
# Cbc0038I Pass  12: suminf.    0.10000 (1) obj. -0.9 iterations 8
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Before mini branch and bound, 21 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Full problem 132 rows 103 columns, reduced to 92 rows 68 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -5 (0.05 seconds)
# Cbc0038I Round again with cutoff of -6.54113
# Cbc0038I Pass  13: suminf.    9.92426 (30) obj. -6.54113 iterations 7
# Cbc0038I Pass  14: suminf.   11.94287 (42) obj. -6.54113 iterations 13
# Cbc0038I Pass  15: suminf.   11.98799 (43) obj. -6.54113 iterations 3
# Cbc0038I Pass  16: suminf.    9.49414 (44) obj. -6.54113 iterations 10
# Cbc0038I Pass  17: suminf.    9.10974 (44) obj. -6.54113 iterations 4
# Cbc0038I Pass  18: suminf.    5.67147 (22) obj. -6.54113 iterations 14
# Cbc0038I Pass  19: suminf.    6.38970 (30) obj. -6.54113 iterations 3
# Cbc0038I Pass  20: suminf.    5.31215 (25) obj. -6.54113 iterations 6
# Cbc0038I Pass  21: suminf.    7.23157 (24) obj. -6.54113 iterations 5
# Cbc0038I Pass  22: suminf.    8.57708 (32) obj. -6.54113 iterations 11
# Cbc0038I Pass  23: suminf.    8.57708 (32) obj. -6.54113 iterations 0
# Cbc0038I Pass  24: suminf.    6.54014 (27) obj. -6.54113 iterations 10
# Cbc0038I Pass  25: suminf.    6.00653 (21) obj. -6.54113 iterations 3
# Cbc0038I Pass  26: suminf.    9.92194 (36) obj. -6.54113 iterations 4
# Cbc0038I Pass  27: suminf.   11.15956 (36) obj. -6.54113 iterations 14
# Cbc0038I Pass  28: suminf.   12.37478 (38) obj. -6.54113 iterations 3
# Cbc0038I Pass  29: suminf.    7.75452 (29) obj. -6.54113 iterations 8
# Cbc0038I Pass  30: suminf.    7.85567 (30) obj. -6.54113 iterations 1
# Cbc0038I Pass  31: suminf.    6.16326 (22) obj. -6.54113 iterations 6
# Cbc0038I Pass  32: suminf.    6.38970 (30) obj. -6.54113 iterations 3
# Cbc0038I Pass  33: suminf.    5.31215 (25) obj. -6.54113 iterations 6
# Cbc0038I Pass  34: suminf.    7.23157 (24) obj. -6.54113 iterations 5
# Cbc0038I Pass  35: suminf.    8.57708 (32) obj. -6.54113 iterations 11
# Cbc0038I Pass  36: suminf.    8.57708 (32) obj. -6.54113 iterations 0
# Cbc0038I Pass  37: suminf.    6.54014 (27) obj. -6.54113 iterations 10
# Cbc0038I Pass  38: suminf.    6.00653 (21) obj. -6.54113 iterations 3
# Cbc0038I Pass  39: suminf.    9.92194 (36) obj. -6.54113 iterations 4
# Cbc0038I Pass  40: suminf.   11.15956 (36) obj. -6.54113 iterations 13
# Cbc0038I Pass  41: suminf.   12.37478 (38) obj. -6.54113 iterations 3
# Cbc0038I Pass  42: suminf.    6.12191 (38) obj. -6.54113 iterations 10
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 34 integers at bound fixed and 0 continuous of which 9 were internal integer and 0 internal continuous
# Cbc0038I Full problem 132 rows 103 columns, reduced to 74 rows 55 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -5 - took 0.05 seconds
# Cbc0012I Integer solution of -5 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 132 rows 103 columns, reduced to 48 rows 33 columns
# Cbc0031I 18 added rows had average density of 69.833333
# Cbc0013I At root node, 18 cuts changed objective from -11.412231 to -8.7599277 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 11 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.062 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1773 row cuts average 86.2 elements, 0 column cuts (0 active)  in 0.088 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 211 row cuts average 46.5 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -5 best solution, best possible -8.7324324 (0.61 seconds)
# Cbc0001I Search completed - best objective -5, took 4569 iterations and 12 nodes (0.73 seconds)
# Cbc0032I Strong branching done 350 times (4615 iterations), fathomed 3 nodes and fixed 5 variables
# Cbc0035I Maximum depth 4, 28 variables fixed on reduced cost
# Cuts at root node changed objective from -11.4122 to -8.73243
# Probing was tried 100 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.062 seconds)
# Gomory was tried 134 times and created 1874 cuts of which 0 were active after adding rounds of cuts (0.099 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
# TwoMirCuts was tried 134 times and created 450 cuts of which 0 were active after adding rounds of cuts (0.038 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ImplicationCuts was tried 34 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               12
# Total iterations:               4569
# Time (CPU seconds):             0.72
# Time (Wallclock seconds):       0.74
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.72   (Wallclock seconds):       0.74
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/eb604f09a2f84bfb90636d3a63a9c68c-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/eb604f09a2f84bfb90636d3a63a9c68c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1874 RHS
# At line 2198 BOUNDS
# At line 2463 ENDATA
# Problem MODEL has 323 rows, 264 columns and 993 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 17.5486 - 0.00 seconds
# Cgl0003I 4 fixed, 114 tightened bounds, 40 strengthened rows, 0 substitutions
# Cgl0003I 3 fixed, 60 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 3 fixed, 42 tightened bounds, 44 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 20 tightened bounds, 34 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 10 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 11 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 131 rows, 99 columns (99 integer (52 of which binary)) and 571 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 55 integers unsatisfied sum - 17.2554
# Cbc0038I Pass   1: suminf.    8.96228 (47) obj. -1 iterations 33
# Cbc0038I Pass   2: suminf.    4.28571 (18) obj. -0.623377 iterations 7
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 0 iterations 4
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 131 rows 99 columns, reduced to 92 rows 60 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -3 (0.05 seconds)
# Cbc0038I Round again with cutoff of -4.64422
# Cbc0038I Pass   4: suminf.   10.21208 (51) obj. -4.64422 iterations 4
# Cbc0038I Pass   5: suminf.   12.54215 (52) obj. -4.64422 iterations 9
# Cbc0038I Pass   6: suminf.    8.34267 (38) obj. -4.64422 iterations 4
# Cbc0038I Pass   7: suminf.   11.74344 (52) obj. -4.64422 iterations 8
# Cbc0038I Pass   8: suminf.    5.94789 (26) obj. -4.64422 iterations 3
# Cbc0038I Pass   9: suminf.    9.71693 (53) obj. -5.53691 iterations 6
# Cbc0038I Pass  10: suminf.   10.17787 (52) obj. -4.64422 iterations 2
# Cbc0038I Pass  11: suminf.    8.38777 (38) obj. -4.64422 iterations 17
# Cbc0038I Pass  12: suminf.    8.38777 (38) obj. -4.64422 iterations 2
# Cbc0038I Pass  13: suminf.   10.92035 (52) obj. -4.98528 iterations 9
# Cbc0038I Pass  14: suminf.   11.39926 (53) obj. -4.64422 iterations 4
# Cbc0038I Pass  15: suminf.    8.03805 (35) obj. -4.64422 iterations 7
# Cbc0038I Pass  16: suminf.    7.41046 (41) obj. -4.64422 iterations 3
# Cbc0038I Pass  17: suminf.    6.36620 (22) obj. -4.64422 iterations 8
# Cbc0038I Pass  18: suminf.    6.64032 (24) obj. -4.64422 iterations 3
# Cbc0038I Pass  19: suminf.   10.86535 (52) obj. -5.0669 iterations 4
# Cbc0038I Pass  20: suminf.   10.55449 (51) obj. -4.64422 iterations 3
# Cbc0038I Pass  21: suminf.   10.98311 (44) obj. -4.64422 iterations 11
# Cbc0038I Pass  22: suminf.   12.75608 (45) obj. -4.64422 iterations 1
# Cbc0038I Pass  23: suminf.   11.38453 (54) obj. -4.64422 iterations 5
# Cbc0038I Pass  24: suminf.   10.35840 (53) obj. -4.64422 iterations 6
# Cbc0038I Pass  25: suminf.    8.03805 (35) obj. -4.64422 iterations 5
# Cbc0038I Pass  26: suminf.    7.41046 (41) obj. -4.64422 iterations 3
# Cbc0038I Pass  27: suminf.    6.36620 (22) obj. -4.64422 iterations 8
# Cbc0038I Pass  28: suminf.    6.64032 (24) obj. -4.64422 iterations 3
# Cbc0038I Pass  29: suminf.   10.86535 (52) obj. -5.0669 iterations 4
# Cbc0038I Pass  30: suminf.   10.55449 (51) obj. -4.64422 iterations 3
# Cbc0038I Pass  31: suminf.   10.98311 (44) obj. -4.64422 iterations 9
# Cbc0038I Pass  32: suminf.   12.75608 (45) obj. -4.64422 iterations 1
# Cbc0038I Pass  33: suminf.   11.38453 (54) obj. -4.64422 iterations 4
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 131 rows 99 columns, reduced to 92 rows 60 columns
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -3 - took 0.05 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0038I Full problem 131 rows 99 columns, reduced to 79 rows 50 columns
# Cbc0031I 21 added rows had average density of 58.238095
# Cbc0013I At root node, 21 cuts changed objective from -10.443076 to -5.6771383 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 53 row cuts average 3.5 elements, 0 column cuts (3 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2053 row cuts average 81.5 elements, 0 column cuts (0 active)  in 0.071 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.030 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 234 row cuts average 42.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -3 best solution, best possible -5.6771383 (0.49 seconds)
# Cbc0001I Search completed - best objective -3, took 3859 iterations and 8 nodes (0.58 seconds)
# Cbc0032I Strong branching done 298 times (3635 iterations), fathomed 2 nodes and fixed 7 variables
# Cbc0035I Maximum depth 3, 20 variables fixed on reduced cost
# Cuts at root node changed objective from -10.4431 to -5.67714
# ...
# Cbc0038I Full problem 136 rows 101 columns, reduced to 87 rows 51 columns
# Cbc0031I 18 added rows had average density of 67.055556
# Cbc0013I At root node, 18 cuts changed objective from -13.994145 to -11.0919 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 33 row cuts average 2.6 elements, 3 column cuts (11 active)  in 0.066 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2014 row cuts average 90.9 elements, 0 column cuts (0 active)  in 0.098 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 228 row cuts average 49.7 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -7 best solution, best possible -11.091772 (0.61 seconds)
# Cbc0016I Integer solution of -8 found by strong branching after 4672 iterations and 30 nodes (0.81 seconds)
# Cbc0001I Search completed - best objective -8, took 4901 iterations and 34 nodes (0.82 seconds)
# Cbc0032I Strong branching done 704 times (9730 iterations), fathomed 9 nodes and fixed 19 variables
# Cbc0035I Maximum depth 10, 65 variables fixed on reduced cost
# Cuts at root node changed objective from -13.9941 to -11.0918
# Probing was tried 100 times and created 36 cuts of which 8 were active after adding rounds of cuts (0.066 seconds)
# Gomory was tried 165 times and created 2144 cuts of which 0 were active after adding rounds of cuts (0.113 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
# TwoMirCuts was tried 165 times and created 458 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 60 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               34
# Total iterations:               4901
# Time (CPU seconds):             0.83
# Time (Wallclock seconds):       0.83
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.83   (Wallclock seconds):       0.83
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c1410616ec16403683168a05277a117d-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/c1410616ec16403683168a05277a117d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1874 RHS
# At line 2198 BOUNDS
# At line 2463 ENDATA
# Problem MODEL has 323 rows, 264 columns and 993 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 5.09186 - 0.00 seconds
# Cgl0003I 6 fixed, 88 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 59 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 20 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 10 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 7 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 128 rows, 96 columns (96 integer (52 of which binary)) and 544 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 4 integer variables out of 96 objects (96 integer) have costs - high priority
# Cbc0045I branch on satisfied Y create fake objective Y random cost Y
# Cbc0038I Initial state - 72 integers unsatisfied sum - 18.6035
# Cbc0038I Pass   1: suminf.    3.66667 (11) obj. 0 iterations 27
# Cbc0038I Pass   2: suminf.    3.66667 (11) obj. 0 iterations 0
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 0 iterations 1
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Before mini branch and bound, 24 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Full problem 128 rows 96 columns, reduced to 79 rows 54 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -1.15838
# Cbc0038I Pass   4: suminf.    9.03333 (33) obj. -1.15838 iterations 3
# Cbc0038I Pass   5: suminf.    7.60895 (33) obj. -1.15838 iterations 3
# Cbc0038I Pass   6: suminf.    5.27408 (16) obj. -1.18342 iterations 8
# Cbc0038I Pass   7: suminf.    5.58547 (18) obj. -1.15838 iterations 2
# Cbc0038I Pass   8: suminf.    5.63367 (17) obj. -1.15838 iterations 5
# Cbc0038I Pass   9: suminf.    6.40960 (22) obj. -1.15838 iterations 3
# Cbc0038I Pass  10: suminf.    6.93541 (23) obj. -1.15838 iterations 1
# Cbc0038I Pass  11: suminf.    5.93085 (19) obj. -1.15838 iterations 4
# Cbc0038I Pass  12: suminf.    4.68282 (17) obj. -1.15838 iterations 4
# Cbc0038I Pass  13: suminf.   11.21779 (52) obj. -1.15838 iterations 19
# Cbc0038I Pass  14: suminf.    9.65134 (41) obj. -1.15838 iterations 5
# Cbc0038I Pass  15: suminf.    3.40090 (21) obj. -1.15838 iterations 8
# Cbc0038I Pass  16: suminf.    3.40090 (21) obj. -1.15838 iterations 0
# Cbc0038I Pass  17: suminf.    6.93541 (23) obj. -1.15838 iterations 5
# Cbc0038I Pass  18: suminf.    6.93541 (23) obj. -1.15838 iterations 0
# Cbc0038I Pass  19: suminf.    5.64362 (19) obj. -1.15838 iterations 4
# Cbc0038I Pass  20: suminf.    5.94104 (20) obj. -1.15838 iterations 5
# Cbc0038I Pass  21: suminf.    3.71333 (24) obj. -1.15838 iterations 4
# Cbc0038I Pass  22: suminf.    3.71333 (24) obj. -1.15838 iterations 1
# Cbc0038I Pass  23: suminf.    4.17362 (18) obj. -1.15838 iterations 5
# Cbc0038I Pass  24: suminf.    4.33102 (18) obj. -1.15838 iterations 4
# Cbc0038I Pass  25: suminf.    3.71333 (24) obj. -1.15838 iterations 3
# Cbc0038I Pass  26: suminf.   10.66276 (43) obj. -1.15838 iterations 15
# Cbc0038I Pass  27: suminf.   10.66276 (43) obj. -1.15838 iterations 1
# Cbc0038I Pass  28: suminf.    9.65230 (35) obj. -1.15838 iterations 10
# Cbc0038I Pass  29: suminf.    8.29008 (31) obj. -1.15838 iterations 8
# Cbc0038I Pass  30: suminf.    8.57856 (30) obj. -1.15838 iterations 3
# Cbc0038I Pass  31: suminf.    8.81636 (39) obj. -1.15838 iterations 4
# Cbc0038I Pass  32: suminf.    8.81636 (39) obj. -1.15838 iterations 0
# Cbc0038I Pass  33: suminf.    5.63135 (32) obj. -1.15838 iterations 4
# Cbc0038I Pass  34: suminf.    5.63135 (32) obj. -1.15838 iterations 0
# Cbc0038I Pass  35: suminf.    8.26538 (40) obj. -1.15838 iterations 6
# Cbc0038I Pass  36: suminf.    8.26538 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  37: suminf.    8.27792 (32) obj. -1.15838 iterations 7
# Cbc0038I Pass  38: suminf.    8.29103 (50) obj. -1.15838 iterations 1
# Cbc0038I Pass  39: suminf.   10.12442 (41) obj. -1.15838 iterations 5
# Cbc0038I Pass  40: suminf.    8.27792 (32) obj. -1.15838 iterations 2
# Cbc0038I Pass  41: suminf.   12.96719 (51) obj. -1.15838 iterations 14
# Cbc0038I Pass  42: suminf.   10.63510 (50) obj. -1.15838 iterations 5
# Cbc0038I Pass  43: suminf.    8.62228 (40) obj. -1.15838 iterations 6
# Cbc0038I Pass  44: suminf.    8.62228 (40) obj. -1.15838 iterations 1
# Cbc0038I Pass  45: suminf.    8.40278 (31) obj. -1.15838 iterations 5
# Cbc0038I Pass  46: suminf.    8.40278 (31) obj. -1.15838 iterations 0
# Cbc0038I Pass  47: suminf.    9.77648 (41) obj. -1.15838 iterations 3
# Cbc0038I Pass  48: suminf.    9.77648 (41) obj. -1.15838 iterations 0
# Cbc0038I Pass  49: suminf.   13.74184 (56) obj. -1.15838 iterations 19
# Cbc0038I Pass  50: suminf.    6.80169 (52) obj. -1.15838 iterations 5
# Cbc0038I Pass  51: suminf.    9.89534 (44) obj. -1.15838 iterations 9
# Cbc0038I Pass  52: suminf.    9.01328 (34) obj. -1.15838 iterations 4
# Cbc0038I Pass  53: suminf.    5.13876 (20) obj. -1.15838 iterations 5
# Cbc0038I Pass  54: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  55: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  56: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  57: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass  58: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass  59: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass  60: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass  61: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  62: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  63: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  64: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass  65: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass  66: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass  67: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass  68: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  69: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  70: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  71: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass  72: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass  73: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass  74: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass  75: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  76: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  77: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  78: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass  79: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass  80: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass  81: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass  82: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  83: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  84: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  85: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass  86: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass  87: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass  88: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass  89: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  90: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  91: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  92: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass  93: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass  94: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass  95: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass  96: suminf.    5.80113 (40) obj. -1.15838 iterations 4
# Cbc0038I Pass  97: suminf.    5.80113 (40) obj. -1.15838 iterations 0
# Cbc0038I Pass  98: suminf.    7.35090 (32) obj. -1.15838 iterations 3
# Cbc0038I Pass  99: suminf.    7.35090 (32) obj. -1.15838 iterations 1
# Cbc0038I Pass 100: suminf.    4.19761 (22) obj. -1.15838 iterations 5
# Cbc0038I Pass 101: suminf.    4.19761 (22) obj. -1.15838 iterations 0
# Cbc0038I Pass 102: suminf.    5.13876 (20) obj. -1.15838 iterations 4
# Cbc0038I Pass 103: suminf.    5.13338 (26) obj. -1.15838 iterations 8
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 128 rows 96 columns, reduced to 119 rows 85 columns - 2 fixed gives 107, 75 - ok now
# Cbc0038I Full problem 128 rows 96 columns, reduced to 107 rows 75 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 0 - took 0.04 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 128 rows 96 columns, reduced to 79 rows 54 columns
# Cbc0031I 10 added rows had average density of 29.4
# Cbc0013I At root node, 50 cuts changed objective from -2.5846916 to 2.2060137 in 8 passes
# Cbc0014I Cut generator 0 (Probing) - 8 row cuts average 3.9 elements, 1 column cuts (1 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 209 row cuts average 57.4 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 265 row cuts average 40.7 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 0, took 342 iterations and 0 nodes (0.10 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -2.58469 to 2.20601
# Probing was tried 8 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Gomory was tried 8 times and created 209 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 8 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 8 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 8 times and created 265 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -0.00000000
# Enumerated nodes:               0
# Total iterations:               342
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.11
#
# CPU times: user 375 ms, sys: 9.69 ms, total: 385 ms
# Wall time: 14.3 s
# 1389.0

# %%
# %%time
reduce(operator.mul, (collect_geodes(bp, 32) for bp in bps[:3]))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7868cb7420f5449cb849d150a127ea33-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/7868cb7420f5449cb849d150a127ea33-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 440 COLUMNS
# At line 2514 RHS
# At line 2950 BOUNDS
# At line 3303 ENDATA
# Problem MODEL has 435 rows, 352 columns and 1337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 26.3359 - 0.00 seconds
# Cgl0003I 3 fixed, 149 tightened bounds, 33 strengthened rows, 0 substitutions
# Cgl0003I 3 fixed, 89 tightened bounds, 31 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 44 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 31 tightened bounds, 44 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 22 tightened bounds, 46 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 36 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 11 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 205 rows, 153 columns (153 integer (82 of which binary)) and 918 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 120 integers unsatisfied sum - 36.5978
# Cbc0038I Pass   1: suminf.    4.75000 (17) obj. 0 iterations 72
# Cbc0038I Pass   2: suminf.   11.87500 (35) obj. 0 iterations 4
# Cbc0038I Pass   3: suminf.    4.50000 (9) obj. 0 iterations 4
# Cbc0038I Pass   4: suminf.    0.00000 (0) obj. 0 iterations 2
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Rounding solution of -1 is better than previous of 0
#
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Full problem 205 rows 153 columns, reduced to 161 rows 104 columns - 2 fixed gives 155, 99 - still too large
# Cbc0038I Full problem 205 rows 153 columns, reduced to 133 rows 86 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -3.76747
# Cbc0038I Pass   5: suminf.   13.74991 (58) obj. -3.76747 iterations 13
# Cbc0038I Pass   6: suminf.   12.96655 (58) obj. -3.76747 iterations 1
# Cbc0038I Pass   7: suminf.    8.05312 (25) obj. -4.04063 iterations 25
# Cbc0038I Pass   8: suminf.   11.87008 (48) obj. -3.76747 iterations 6
# Cbc0038I Pass   9: suminf.    8.05312 (25) obj. -4.04063 iterations 6
# Cbc0038I Pass  10: suminf.   14.45175 (55) obj. -3.76747 iterations 30
# Cbc0038I Pass  11: suminf.   17.44176 (56) obj. -3.76747 iterations 8
# Cbc0038I Pass  12: suminf.   11.75873 (49) obj. -3.76747 iterations 17
# Cbc0038I Pass  13: suminf.   14.12717 (42) obj. -3.76747 iterations 9
# Cbc0038I Pass  14: suminf.    7.35938 (26) obj. -3.80134 iterations 12
# Cbc0038I Pass  15: suminf.    7.42540 (29) obj. -3.76747 iterations 6
# Cbc0038I Pass  16: suminf.    3.48607 (19) obj. -3.76747 iterations 14
# Cbc0038I Pass  17: suminf.    3.48607 (19) obj. -3.76747 iterations 5
# Cbc0038I Pass  18: suminf.    2.17475 (11) obj. -3.76747 iterations 5
# Cbc0038I Pass  19: suminf.    5.54464 (35) obj. -4.61161 iterations 41
# Cbc0038I Pass  20: suminf.    4.74021 (30) obj. -3.76747 iterations 9
# Cbc0038I Pass  21: suminf.    7.62958 (37) obj. -3.76747 iterations 7
# Cbc0038I Pass  22: suminf.    7.04121 (31) obj. -3.76747 iterations 5
# Cbc0038I Pass  23: suminf.    7.62958 (37) obj. -3.76747 iterations 4
# Cbc0038I Pass  24: suminf.    7.96859 (41) obj. -3.76747 iterations 16
# Cbc0038I Pass  25: suminf.    6.52797 (37) obj. -3.76747 iterations 9
# Cbc0038I Pass  26: suminf.   10.65971 (40) obj. -3.76747 iterations 12
# Cbc0038I Pass  27: suminf.    8.41030 (40) obj. -3.76747 iterations 9
# Cbc0038I Pass  28: suminf.   10.62819 (41) obj. -3.76747 iterations 8
# Cbc0038I Pass  29: suminf.    9.12224 (34) obj. -3.76747 iterations 3
# Cbc0038I Pass  30: suminf.   13.62777 (50) obj. -3.76747 iterations 24
# Cbc0038I Pass  31: suminf.    9.38222 (33) obj. -3.76747 iterations 12
# Cbc0038I Pass  32: suminf.   12.38321 (39) obj. -3.76747 iterations 7
# Cbc0038I Pass  33: suminf.    9.50607 (32) obj. -3.76747 iterations 7
# Cbc0038I Pass  34: suminf.   18.84439 (78) obj. -3.76747 iterations 30
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 205 rows 153 columns, reduced to 180 rows 124 columns - 0 fixed gives 180, 124 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -1 - took 0.02 seconds
# Cbc0012I Integer solution of -1 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 205 rows 153 columns, reduced to 161 rows 104 columns - 13 fixed gives 75, 47 - ok now
# Cbc0038I Full problem 205 rows 153 columns, reduced to 39 rows 24 columns
# Cbc0031I 28 added rows had average density of 108.39286
# Cbc0013I At root node, 28 cuts changed objective from -19.675647 to -15.816466 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 91 row cuts average 4.3 elements, 5 column cuts (7 active)  in 0.114 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 3420 row cuts average 127.9 elements, 0 column cuts (0 active)  in 0.227 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.062 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 301 row cuts average 95.2 elements, 0 column cuts (0 active)  in 0.046 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -1 best solution, best possible -15.816466 (1.28 seconds)
# Cbc0038I Full problem 205 rows 153 columns, reduced to 76 rows 49 columns
# Cbc0004I Integer solution of -11 found after 7298 iterations and 55 nodes (1.80 seconds)
# Cbc0001I Search completed - best objective -11, took 9336 iterations and 86 nodes (2.13 seconds)
# Cbc0032I Strong branching done 1512 times (31080 iterations), fathomed 5 nodes and fixed 34 variables
# Cbc0035I Maximum depth 22, 53 variables fixed on reduced cost
# Cuts at root node changed objective from -19.6756 to -15.8165
# Probing was tried 100 times and created 96 cuts of which 2 were active after adding rounds of cuts (0.114 seconds)
# Gomory was tried 200 times and created 3576 cuts of which 0 were active after adding rounds of cuts (0.273 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.029 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.062 seconds)
# TwoMirCuts was tried 100 times and created 301 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ImplicationCuts was tried 46 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.00000000
# Enumerated nodes:               86
# Total iterations:               9336
# Time (CPU seconds):             2.09
# Time (Wallclock seconds):       2.15
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.09   (Wallclock seconds):       2.16
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/499bec347b564d5db4512327de80558a-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/499bec347b564d5db4512327de80558a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 440 COLUMNS
# At line 2514 RHS
# At line 2950 BOUNDS
# At line 3303 ENDATA
# Problem MODEL has 435 rows, 352 columns and 1337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 29.6337 - 0.00 seconds
# Cgl0003I 4 fixed, 127 tightened bounds, 51 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 103 tightened bounds, 47 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 64 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 27 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 22 tightened bounds, 39 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 20 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 14 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 10 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 208 rows, 155 columns (155 integer (84 of which binary)) and 918 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 82 integers unsatisfied sum - 22.0073
# Cbc0038I Pass   1: suminf.    7.24561 (22) obj. 0 iterations 58
# Cbc0038I Pass   2: suminf.    7.24561 (22) obj. 0 iterations 0
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 0 iterations 6
# Cbc0038I Solution found of 0
# Cbc0038I Cleaned solution of 0
# Cbc0038I Rounding solution of -1 is better than previous of 0
#
# Cbc0038I Before mini branch and bound, 50 integers at bound fixed and 0 continuous of which 13 were internal integer and 0 internal continuous
# Cbc0038I Full problem 208 rows 155 columns, reduced to 140 rows 92 columns - 1 fixed gives 134, 86 - still too large
# Cbc0038I Full problem 208 rows 155 columns, reduced to 116 rows 78 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -4.20437
# Cbc0038I Pass   4: suminf.    9.74131 (37) obj. -4.20437 iterations 4
# Cbc0038I Pass   5: suminf.    9.74131 (37) obj. -4.20437 iterations 0
# Cbc0038I Pass   6: suminf.    4.47059 (12) obj. -5.11765 iterations 14
# Cbc0038I Pass   7: suminf.    3.58692 (18) obj. -4.20437 iterations 2
# Cbc0038I Pass   8: suminf.   12.00035 (44) obj. -4.20437 iterations 26
# Cbc0038I Pass   9: suminf.    9.21637 (35) obj. -4.20437 iterations 8
# Cbc0038I Pass  10: suminf.    3.21053 (18) obj. -4.70588 iterations 8
# Cbc0038I Pass  11: suminf.    5.67762 (27) obj. -4.20437 iterations 3
# Cbc0038I Pass  12: suminf.    3.94118 (11) obj. -4.70588 iterations 7
# Cbc0038I Pass  13: suminf.    3.58692 (18) obj. -4.20437 iterations 4
# Cbc0038I Pass  14: suminf.    4.41176 (12) obj. -4.58824 iterations 2
# Cbc0038I Pass  15: suminf.    6.75294 (39) obj. -10.4365 iterations 33
# Cbc0038I Pass  16: suminf.    3.41176 (9) obj. -8.58824 iterations 11
# Cbc0038I Pass  17: suminf.    1.66498 (15) obj. -4.20437 iterations 3
# Cbc0038I Pass  18: suminf.    1.35294 (10) obj. -4.23529 iterations 1
# Cbc0038I Pass  19: suminf.   11.25397 (37) obj. -4.20437 iterations 10
# Cbc0038I Pass  20: suminf.    1.88235 (6) obj. -6.17647 iterations 9
# Cbc0038I Pass  21: suminf.    3.51099 (12) obj. -4.20437 iterations 2
# Cbc0038I Pass  22: suminf.    3.35294 (8) obj. -4.76471 iterations 1
# Cbc0038I Pass  23: suminf.   12.04905 (43) obj. -4.20437 iterations 19
# Cbc0038I Pass  24: suminf.    4.54509 (35) obj. -4.20437 iterations 9
# Cbc0038I Pass  25: suminf.   13.25367 (38) obj. -4.20437 iterations 5
# Cbc0038I Pass  26: suminf.    5.83856 (30) obj. -4.20437 iterations 4
# Cbc0038I Pass  27: suminf.   10.37244 (40) obj. -4.20437 iterations 17
# Cbc0038I Pass  28: suminf.   17.95647 (68) obj. -4.20437 iterations 12
# Cbc0038I Pass  29: suminf.   14.55515 (53) obj. -4.20437 iterations 9
# Cbc0038I Pass  30: suminf.   18.86336 (72) obj. -4.20437 iterations 7
# Cbc0038I Pass  31: suminf.   13.91757 (47) obj. -4.20437 iterations 2
# Cbc0038I Pass  32: suminf.   13.31002 (40) obj. -4.20437 iterations 3
# Cbc0038I Pass  33: suminf.    9.57193 (31) obj. -4.20437 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 26 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 208 rows 155 columns, reduced to 175 rows 120 columns - 7 fixed gives 130, 90 - still too large
# Cbc0038I Full problem 208 rows 155 columns, reduced to 125 rows 87 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of -1 - took 0.02 seconds
# Cbc0012I Integer solution of -1 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 208 rows 155 columns, reduced to 140 rows 92 columns - 14 fixed gives 40, 28 - ok now
# Cbc0038I Full problem 208 rows 155 columns, reduced to 13 rows 11 columns
# Cbc0031I 27 added rows had average density of 115.62963
# Cbc0013I At root node, 27 cuts changed objective from -24.044617 to -18.083102 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 21 row cuts average 4.0 elements, 7 column cuts (9 active)  in 0.113 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2617 row cuts average 132.1 elements, 0 column cuts (0 active)  in 0.216 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.026 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.058 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 264 row cuts average 88.7 elements, 0 column cuts (0 active)  in 0.047 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -1 best solution, best possible -18.083102 (1.17 seconds)
# Cbc0004I Integer solution of -10 found after 5317 iterations and 21 nodes (1.41 seconds)
# Cbc0016I Integer solution of -13 found by strong branching after 5362 iterations and 24 nodes (1.42 seconds)
# Cbc0038I Full problem 208 rows 155 columns, reduced to 116 rows 71 columns - 7 fixed gives 64, 41 - ok now
# Cbc0038I Full problem 208 rows 155 columns, reduced to 57 rows 37 columns
# Cbc0001I Search completed - best objective -13, took 8854 iterations and 99 nodes (2.25 seconds)
# Cbc0032I Strong branching done 1754 times (32069 iterations), fathomed 17 nodes and fixed 28 variables
# Cbc0035I Maximum depth 14, 234 variables fixed on reduced cost
# Cuts at root node changed objective from -24.0446 to -18.0831
# Probing was tried 100 times and created 28 cuts of which 2 were active after adding rounds of cuts (0.113 seconds)
# Gomory was tried 219 times and created 2743 cuts of which 0 were active after adding rounds of cuts (0.277 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.058 seconds)
# TwoMirCuts was tried 100 times and created 264 cuts of which 0 were active after adding rounds of cuts (0.047 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.00000000
# Enumerated nodes:               99
# Total iterations:               8854
# Time (CPU seconds):             2.22
# Time (Wallclock seconds):       2.27
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.22   (Wallclock seconds):       2.27
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/wleftwich/.pyenv/versions/3.11.0/envs/aoc/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6f12519bbb57497cbca74edb658cfc21-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/6f12519bbb57497cbca74edb658cfc21-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 440 COLUMNS
# At line 2514 RHS
# At line 2950 BOUNDS
# At line 3303 ENDATA
# Problem MODEL has 435 rows, 352 columns and 1337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 42.9455 - 0.00 seconds
# Cgl0003I 5 fixed, 136 tightened bounds, 52 strengthened rows, 1 substitutions
# Cgl0003I 2 fixed, 92 tightened bounds, 81 strengthened rows, 2 substitutions
# Cgl0003I 2 fixed, 51 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 26 tightened bounds, 40 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 11 tightened bounds, 27 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 10 tightened bounds, 21 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 8 tightened bounds, 2 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 1 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 1 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 207 rows, 157 columns (157 integer (84 of which binary)) and 922 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 118 integers unsatisfied sum - 39.9879
# Cbc0038I Pass   1: suminf.   17.50000 (35) obj. -10 iterations 67
# Cbc0038I Pass   2: suminf.   12.71364 (65) obj. -9.91136 iterations 8
# Cbc0038I Pass   3: suminf.   14.67043 (54) obj. -8.81053 iterations 10
# Cbc0038I Pass   4: suminf.   16.35146 (52) obj. -8.81053 iterations 2
# Cbc0038I Pass   5: suminf.   15.53509 (52) obj. -5 iterations 3
# Cbc0038I Pass   6: suminf.   15.84444 (59) obj. -5 iterations 3
# Cbc0038I Pass   7: suminf.   14.95614 (51) obj. -5 iterations 2
# Cbc0038I Pass   8: suminf.    6.68421 (34) obj. -5 iterations 23
# Cbc0038I Pass   9: suminf.    0.00000 (0) obj. -5 iterations 6
# Cbc0038I Solution found of -5
# Cbc0038I Cleaned solution of -5
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 207 rows 157 columns, reduced to 150 rows 106 columns - 4 fixed gives 123, 86 - still too large
# Cbc0038I Full problem 207 rows 157 columns, reduced to 109 rows 78 columns
# Cbc0038I Mini branch and bound improved solution from -5 to -21 (0.09 seconds)
# Cbc0038I Round again with cutoff of -23.1531
# Cbc0038I Pass  10: suminf.   19.95251 (83) obj. -23.1531 iterations 27
# Cbc0038I Pass  11: suminf.   15.65270 (84) obj. -23.1531 iterations 12
# Cbc0038I Pass  12: suminf.   14.78718 (86) obj. -23.1531 iterations 6
# Cbc0038I Pass  13: suminf.   26.57362 (90) obj. -23.1531 iterations 26
# Cbc0038I Pass  14: suminf.   18.00611 (69) obj. -23.1531 iterations 5
# Cbc0038I Pass  15: suminf.   18.56113 (65) obj. -23.1531 iterations 5
# Cbc0038I Pass  16: suminf.   20.09387 (80) obj. -23.1531 iterations 24
# Cbc0038I Pass  17: suminf.   22.98831 (80) obj. -23.1531 iterations 6
# Cbc0038I Pass  18: suminf.   22.56685 (88) obj. -23.1531 iterations 15
# Cbc0038I Pass  19: suminf.   18.79974 (61) obj. -23.1531 iterations 10
# Cbc0038I Pass  20: suminf.   18.22169 (63) obj. -23.1531 iterations 8
# Cbc0038I Pass  21: suminf.   16.61792 (65) obj. -23.1531 iterations 19
# Cbc0038I Pass  22: suminf.   14.07357 (62) obj. -23.1531 iterations 7
# Cbc0038I Pass  23: suminf.   19.13443 (69) obj. -23.1531 iterations 16
# Cbc0038I Pass  24: suminf.   15.16711 (56) obj. -23.1531 iterations 10
# Cbc0038I Pass  25: suminf.   13.78845 (57) obj. -23.1531 iterations 5
# Cbc0038I Pass  26: suminf.   16.73059 (60) obj. -23.1531 iterations 11
# Cbc0038I Pass  27: suminf.   13.92460 (59) obj. -23.1531 iterations 8
# Cbc0038I Pass  28: suminf.   14.58582 (58) obj. -23.1531 iterations 2
# Cbc0038I Pass  29: suminf.   14.58582 (58) obj. -23.1531 iterations 0
# Cbc0038I Pass  30: suminf.   18.96291 (62) obj. -23.1531 iterations 17
# Cbc0038I Pass  31: suminf.   17.06483 (59) obj. -23.1531 iterations 4
# Cbc0038I Pass  32: suminf.   17.26210 (58) obj. -23.1531 iterations 8
# Cbc0038I Pass  33: suminf.   12.67220 (55) obj. -23.1531 iterations 8
# Cbc0038I Pass  34: suminf.   13.85558 (58) obj. -23.1531 iterations 5
# Cbc0038I Pass  35: suminf.   15.78867 (58) obj. -23.1531 iterations 17
# Cbc0038I Pass  36: suminf.   12.99678 (51) obj. -23.1531 iterations 7
# Cbc0038I Pass  37: suminf.   11.63429 (43) obj. -23.1531 iterations 13
# Cbc0038I Pass  38: suminf.   12.82196 (56) obj. -23.1531 iterations 13
# Cbc0038I Pass  39: suminf.   14.85883 (62) obj. -23.1531 iterations 17
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 207 rows 157 columns, reduced to 150 rows 105 columns - 11 fixed gives 85, 61 - ok now
# Cbc0038I Full problem 207 rows 157 columns, reduced to 82 rows 58 columns
# Cbc0038I Mini branch and bound did not improve solution (0.11 seconds)
# Cbc0038I After 0.11 seconds - Feasibility pump exiting with objective of -21 - took 0.08 seconds
# Cbc0012I Integer solution of -21 found by feasibility pump after 0 iterations and 0 nodes (0.11 seconds)
# Cbc0038I Full problem 207 rows 157 columns, reduced to 146 rows 101 columns - 11 fixed gives 79, 57 - ok now
# Cbc0038I Full problem 207 rows 157 columns, reduced to 60 rows 48 columns
# Cbc0031I 22 added rows had average density of 119.04545
# Cbc0013I At root node, 22 cuts changed objective from -33.532358 to -27.572658 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 4.7 elements, 2 column cuts (5 active)  in 0.116 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2331 row cuts average 135.0 elements, 0 column cuts (0 active)  in 0.254 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.070 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 318 row cuts average 72.0 elements, 0 column cuts (0 active)  in 0.051 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -21 best solution, best possible -27.572658 (1.27 seconds)
# Cbc0038I Full problem 207 rows 157 columns, reduced to 93 rows 62 columns
# Cbc0038I Full problem 207 rows 157 columns, reduced to 106 rows 66 columns
# Cbc0001I Search completed - best objective -21, took 10238 iterations and 114 nodes (2.54 seconds)
# Cbc0032I Strong branching done 1746 times (36551 iterations), fathomed 17 nodes and fixed 32 variables
# Cbc0035I Maximum depth 14, 258 variables fixed on reduced cost
# Cuts at root node changed objective from -33.5324 to -27.5727
# Probing was tried 100 times and created 8 cuts of which 3 were active after adding rounds of cuts (0.116 seconds)
# Gomory was tried 246 times and created 2452 cuts of which 0 were active after adding rounds of cuts (0.348 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.070 seconds)
# TwoMirCuts was tried 246 times and created 855 cuts of which 0 were active after adding rounds of cuts (0.162 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                21.00000000
# Enumerated nodes:               114
# Total iterations:               10238
# Time (CPU seconds):             2.54
# Time (Wallclock seconds):       2.55
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.54   (Wallclock seconds):       2.55
#
# CPU times: user 70.1 ms, sys: 3.84 ms, total: 74 ms
# Wall time: 7.06 s
# 3003.0
